# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('final_startup_funding.csv')
data.head()
# Out:
#    Sr No Date dd/mm/yyyy Startup Name       Industry Vertical  \
# 0    167      03-04-2015       Swiggy    Online Food Delivery
# 1    168      04-04-2015     Bluegape  Web Content Publishing
# 2    169      04-04-2015     KeepTrax      Location Based App
# 3    170      06-04-2015  InstaLively         Video Streaming
# 4    171      07-04-2015  Pricejugaad        Price Comparison
#
#        City  Location                                     Investors Name  \
# 0           Bangalore                      Accel Partners, SAIF Partners
# 1             Gurgaon                  Rudy Gopalakrishnan, ah! Ventures
# 2  Dallas / Hyderabad                                                NaN
# 3           New Delhi  Rajesh Sawheny , Rajan Anandan, Amit Ranjan, N...
# 4           Hyderabad               Amit Tyagi, Sandeep Acharya & others
#
#   InvestmentnType   Amount
# 0  Private Equity  2000000
# 1    Seed Funding   200000
# 2    Seed Funding  1000000
# 3    Seed Funding   120000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1931 entries, 0 to 1930
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              1931 non-null   int64
#  1   Date dd/mm/yyyy    1931 non-null   object
#  2   Startup Name       1931 non-null   object
#  3   Industry Vertical  1931 non-null   object
#  4   City  Location     1931 non-null   object
#  5   Investors Name     1911 non-null   object
#  6   InvestmentnType    1928 non-null   object
#  7   Amount             1931 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 120.8+ KB

# %%
arr={}
arr['no']=0
arr['<50l']=0
arr['1c']=0
arr['5c']=0
arr['>5c']=0
t=0
k=0
j=0
ans=0
for i in data['Amount']:
    j+=1
    #ans+=val
    if i<5000000:
        arr['<50l']+=1
    elif i<10000000:
        arr['1c']+=1
    elif i<50000000:
        arr['5c']+=1
    else:
        arr['>5c']+=1
value=[arr['<50l'],arr['1c'],arr['5c'],arr['>5c']]
label=['Less than 50 Lakh','Less than 1 Crore','Less than 5 Crore','Greater than 5 Crore']
y=np.array(value)
#print(value)
#mex=[1,1.3,1.3,1.3,1.3,1.3,0,0,0]
mex=[0,0,0,0]
plt.pie(y,labels=label,explode=mex,autopct='%1.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Startup Funding Trends
#
# 1. It is seen that, in the chosen dataset around 66% of the startups are alloted with **less than 50 lakh rupees**.
# 2. We can also see that only around 7% of the startups are funded with more than 5 crores rupees.
# 3. Also startups with less than 1 crore and less then 5 crore funding are 11% and 17% respectively.
# 4. From this chart, it can be observed that most of the startups are funding with **less that 50 lakh rupees**.

# %%
dict={}
for i in data['InvestmentnType']:
    try:
        i=i
        i=i.replace(' ','').replace('\\\\n','').upper()
    except:
        i=i
    if i in dict:
            dict[i]+=1
    else:
            dict[i]=1
            
final={}  
final['Others']=0
for i in dict:
    #print(f"{i} -> {dict[i]}")
    if dict[i]<10:
        final['Others']+=dict[i]
    else:
        final[i]=dict[i]

#for i in final:
    #print(f"{i} -> {final[i]}")
        
funding=list(final.keys())
value=list(final.values())

fig = plt.figure(figsize = (16, 5))
plt.bar(funding, value, color ='maroon',
        width = 0.5)

plt.xlabel("Type of funding")
plt.ylabel("No. of startups")
plt.title("Types of Funding vs Startups")
plt.show()

# %% [markdown]
# ### Types of Funding v/s No of Startup
#
# 1. From the above graph we can see that majority of the startup funding is from **Private Equity**.
# 2. Also a fair amount of startups are funded by **Seed Funding** type of funding.
# 3. Most of the other startups are funding in small portions by Debt Funding, Angel Funding, Series A,B,C,D types of funding.
# 4. So here most of funding is from either **Private Funding** or **Seed Funding** with the former being a majority.

# %%
y=(np.array(value))
#print(value)
#print(funding)
mex=[.5,0,0,.5,.5,1,1,1,1]
plt.pie(y,labels=funding,explode=mex,autopct='%1.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Types of Funding v/s No of Startup
#
# 1. From the above graph we can see that **around 52%** of the startup funding is from **Private Equity**.
# 2. Also a fair amount(*35%*) of startups are funded by **Seed Funding** type of funding.
# 3. Most of the other startups are funding in small portions by Debt Funding, Angel Funding, Series A,B,C,D types of funding.
# 4. So here most of funding is from either **Private Funding** or **Seed FUnding** with the former being a majority.

# %%
dict={}
for i in data['City  Location']:
    try:
        i=i.replace(' ','')
    except:
        i=i    
    if i in dict:
        dict[i]+=1
    else:
        dict[i]=1
#print(dict['Bangalore'],dict['Bengaluru'])
fin={}
fin['Others']=0
fin['Combined']=0
fin['Bangalore']=dict['Bangalore']+dict['Bengaluru']
for i in dict:
    if i!='Bangalore' or i!='Bengaluru':
        try:
            if i=='Bangalore' or i=='Bengaluru':
                fin['Bangalore']+=dic[i]
            elif pd.isna(i):
                k=1
            elif '/' in i:
                fin['Combined']+=1
            elif dict[i]<20:
                fin['Others']+=1
            else:
                fin[i]=dict[i]
        except:
            pass
new_fin={}        
for i in sorted(fin):
    #print(i,fin[i])
    new_fin[i]=fin[i]

# %%
loc=list(i for i in new_fin.keys() if not pd.isna(i))
#print(loc)
value=list(new_fin.values())

fig = plt.figure(figsize = (15, 5))
plt.bar(loc, value, color ='green',
        width = 0.5)

plt.xlabel("Locations")
plt.ylabel("No. of startups")
plt.title("Locations vs Startups")
plt.show()

# %% [markdown]
# ### Types of Funding v/s Startup Location
#
# 1. From the above graph, we see that most of the Startup are emerging from lot of developing city like **Bangalore, Mumbai, New Delhi, Gurgaon**.
# 2. Also we can infer a lot of startups are founded from these cities

# %%
y=np.array(value)
#print(value)
mex=[]
for i in value:
    if i>199:
        mex.append(0)
    else:
        mex.append(.3)
#print(len(value),len(mex))
plt.pie(y,labels=loc,explode=mex,autopct='%1.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Types of Funding v/s Startup Location
#
# #### From the piechart we can see that-
# - **31%** startups from Bangalore
# - **22%** startups from Mumbai
# - **13%** startups from New Delhi
# - **11%** startups from Gurgaon
